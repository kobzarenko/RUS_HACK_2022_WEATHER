# %%
# библиотеки....
import numpy as np 
import pandas as pd 
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Reshape, concatenate,  Flatten
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, SpatialDropout1D, MaxPooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import Callback
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, accuracy_score 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ЧТЕНИЕ И НОРМИРОВАНИЕ ДАННЫХ ИСХОДНОЙ ТАБЛИЦЫ

# %%
df = pd.read_csv('/content/drive/My Drive/Bases/makhachkala_weather_2011_2020_2.csv')

# %%
# нормируем столбцы (6 столбцов), которые по условию задачи
# участвуют в формировании вектора X
x_cols = ['t_air', 'rel_hum', 'P_atm', 'precip', 'wind_dir', 'wind_speed']

# нормировка данных по каждому столбцу к интервалу [0..1]
for col in x_cols:
  m = max(df[col])
  df[col] = df[col] / m

df
# Out:
#                   datetime     t_air  t_soil  t_dew  P_part_water  rel_hum  \
# 0      2011-01-01 00:00:00  0.170984     7.0    5.5          9.01     0.93
# 1      2011-01-01 03:00:00  0.160622     6.0    5.1          8.75     0.92
# 2      2011-01-01 06:00:00  0.150259     6.0    4.9          8.64     0.94
# 3      2011-01-01 09:00:00  0.152850     7.0    3.8          8.00     0.86
# 4      2011-01-01 12:00:00  0.134715     6.0    3.0          7.58     0.86
# ...                    ...       ...     ...    ...           ...      ...
# 29219  2020-12-31 09:00:00  0.111399     6.0    1.8          7.01     0.84
# 29220  2020-12-31 12:00:00  0.121762     6.0    2.4          7.29     0.85
# 29221  2020-12-31 15:00:00  0.113990     5.0    2.0          7.09     0.85
# 29222  2020-12-31 18:00:00  0.119171     2.0    2.0          7.07     0.83
# 29223  2020-12-31 21:00:00  0.098446     4.0    1.7          6.93     0.86
#
#        satur_def     P_atm  precip  wind_dir  wind_speed  shower  snow  fog  \
# 0           0.73  0.970389     0.0  0.833333      0.1875       0     0    0
# 1           0.73  0.969437     0.0  0.861111      0.2500       0     0    0
# 2           0.58  0.969723     0.0  0.916667      0.1875       0     0    0
# 3           1.28  0.969628     0.0  0.861111      0.3750       0     0    0
# 4           1.26  0.970199     0.0  0.888889      0.3750       0     0    0
# ...          ...       ...     ...       ...         ...     ...   ...  ...
# 29219       1.33  0.977625     0.0  0.886111      0.1875       0     0    0
# 29220       1.29  0.976959     0.0  0.802778      0.1250       0     0    0
# 29221       1.25  0.976673     0.0  0.905556      0.0625       0     0    1
# 29222       1.45  0.980577     0.0  0.433333      0.1875       0     0    0
# 29223       1.13  0.979625     0.0  0.363889      0.1875       0     0    0
#
#        strong_wind
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 29219            0
# 29220            0
# 29221            0
# 29222            0
# 29223            0
#
# [29224 rows x 15 columns]

# %% [markdown]
# ФУНКЦИЯ ГЕНЕРАЦИИ ВЫБОРКИ

# %%
# data - исходный датафрейм
# days_count - размер блока данных для X примера (по умолчанию 1 день)
# x_col_names - список колонок c которых генерируются векторы X
# y_col_name - колонка для генерации значений Y

def CreateSamples(data, x_col_names, y_col_name, days_count=1):
  
  block_size = days_count * 8 # размер блока данных

  pos = 0 # начальная позиция текущего смещения в датасете

  # обнуляем списки...
  samples_x = []
  samples_y = []
  
  Ex = False

  while not Ex: # цикл остановится, когда переменная Ex станет истиной 

    if pos + block_size < data.shape[0]: # если не дошли до конца....

      x_vec = []
      for x_col_name in x_col_names:
        x_vec.extend(data[x_col_name][pos:pos+block_size].to_list())
      
      y_vec = data[y_col_name][pos+block_size:pos+block_size+1].to_list()   

      samples_x.append(x_vec)
      samples_y.append(y_vec)

    else:

      Ex = True
    
    pos += 1 # сдвигаем позицию на 1

  # перевод данных в numpy массивы
  samples_x = np.array(samples_x)
  samples_y = np.array(samples_y).astype('float')

  return samples_x, samples_y

# %% [markdown]
# ГЕНЕРАЦИЯ ВЫБОРКИ

# %%
# размер блока данных
days_count = 7

# генерация выборки 
samples_x, samples_y = CreateSamples(df, x_cols, 'snow', days_count)

# рамерность массивов
print(samples_x.shape)
print(samples_y.shape)
# Out:
# (29168, 336)
# (29168, 1)

# %% [markdown]
# МОДЕЛЬ НЕЙРОННОЙ СЕТИ
#
# Данные по 6 парамертам разделяются на 6 паралелльных веток для обработки одномерной сверткой, далее они объединяются и проходят через каскад полносвязных слоев.

# %%
# days_count - размер блока данных в днях

def CreateModel(days_count, activation='linear', dropout=0.1):

  input = Input((days_count*8*6,))
  
  x = Reshape((days_count*8*6, 1))(input)

  # свертка 1-го параметра
  x1 = SpatialDropout1D(dropout)(x[:, days_count*8*0:days_count*8*1, :])
  x1 = Conv1D(20, 7, activation=activation)(x1)
  x1 = MaxPooling1D(2)(x1)
  x1 = Flatten()(x1)

  # свертка 2-го параметра
  x2 = SpatialDropout1D(dropout)(x[:, days_count*8*1:days_count*8*2, :])
  x2 = Conv1D(20, 7, activation=activation)(x2)
  x2 = MaxPooling1D(2)(x2)
  x2 = Flatten()(x2)

  # свертка 3-го параметра
  x3 = SpatialDropout1D(dropout)(x[:, days_count*8*2:days_count*8*3, :])
  x3 = Conv1D(20, 7, activation=activation)(x3)
  x3 = MaxPooling1D(2)(x3)
  x3 = Flatten()(x3)
  
  # свертка 4-го параметра
  x4 = SpatialDropout1D(dropout)(x[:, days_count*8*3:days_count*8*4, :])
  x4 = Conv1D(20, 7, activation=activation)(x4)
  x4 = MaxPooling1D(2)(x4)
  x4 = Flatten()(x4)

  # свертка 5-го параметра
  x5 = SpatialDropout1D(dropout)(x[:, days_count*8*4:days_count*8*5, :])
  x5 = Conv1D(20, 7, activation=activation)(x5)
  x5 = MaxPooling1D(2)(x5)
  x5 = Flatten()(x5)

  # свертка 6-го параметра
  x6 = SpatialDropout1D(dropout)(x[:, days_count*8*5:days_count*8*6, :])
  x6 = Conv1D(20, 7, activation=activation)(x6)
  x6 = MaxPooling1D(2)(x6)
  x6 = Flatten()(x6)

  # оббъединяем результаты свертки в 1 слой
  x = concatenate([x1, x2, x3, x4, x5, x6])

  x = BatchNormalization()(x)
  x = Dense(500, activation=activation)(x)
  x = Dropout(dropout)(x)
  
  x = BatchNormalization()(x)
  x = Dense(200, activation=activation)(x)
  x = Dropout(dropout)(x)

  output = Dense(1, activation='sigmoid')(x) 

  return Model(input, output)

# %% [markdown]
# CALLBACK для фиксации лучшего обучения по метрике RECALL

# %%
# файл для сохранения лучших весов модели
model_save_file = '/content/drive/My Drive/Bases/model_best_sn.h5'

# собственный коллбэк
class MyCallback(Callback):
  
  # инициализация
  def __init__(self, model, x_val, y_val):
    # модель
    self.model = model 
    # проверочная выборка
    self.x_val = x_val 
    self.y_val = y_val
    # начальный счет по средней метрике
    self.score = 0
    # список значений по метрике Recall
    self.recall_list = []
    # список значений по средней метрике
    self.general_list = []
       
  # подсчет метрики Recall для val  
  def calc_metric(self):
    y_pred = self.model.predict(self.x_val)
    y_p = np.around(y_pred).astype(int)
    y_t = np.around(self.y_val).astype(int)
    rec = recall_score(y_t, y_p, average='macro')
    acc = accuracy_score(y_t, y_p)
    return rec, acc
  
  # окончение каждой эпохи....
  def on_epoch_end(self, epoch, logs=None):
    rec, acc = self.calc_metric()
    self.recall_list.append(rec)
    score_0 = (rec + acc)/2
    self.general_list.append(score_0)
    print('\n\nТекущая точность (Recall+Accuracy)/2 =', score_0, '\n')
    if score_0 > self.score:
      self.score = score_0
      print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 =', score_0, '\n')
      self.model.save_weights(model_save_file)   

  # в конце обучения
  def on_train_end(self, logs=None):
    print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ =', self.score, '\n')
  
  # получение списка recall_list
  def get_recall_list(self):
    return self.recall_list

  # получение списка general_list
  def get_general_list(self):
    return self.general_list

# %% [markdown]
# ПАРАМЕТРЫ ОБУЧЕНИЯ

# %%
# параметры обучения

batch_size = 50

dropout = 0.25

activate_function = 'relu'

epochs_count = 50

learning_rate = 1e-4

# %% [markdown]
# ОБУЧЕНИЕ НЕЙРОННОЙ СЕТИ

# %%
# деление выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(samples_x, samples_y, 
                                                  test_size=0.1, random_state=1)

# %%
# настройка весов для классов модели (учет разбаллансировки)
weight_for_0 = 1.0 / (y_train == 0.0).sum()
weight_for_1 = 1.0 / (y_train == 1.0).sum()

class_weight = {0: weight_for_0, 1: weight_for_1}

print(class_weight)
# Out:
# {0: 3.852525330354047e-05, 1: 0.003401360544217687}

# %%
# создание модели
model = CreateModel(days_count=days_count, 
                    activation=activate_function, dropout=dropout)  
cb = MyCallback(model, x_val, y_val)

# %%
# компиляция
model.compile(optimizer=Adam(learning_rate=learning_rate), 
              loss=['binary_crossentropy'], 
              metrics=['accuracy'])

# обучение
history = model.fit(x_train, y_train, 
                    batch_size = batch_size,
                    epochs= epochs_count, 
                    validation_data=(x_val, y_val), 
                    verbose=1, 
                    class_weight = class_weight,
                    callbacks=[cb])
# Out:
# Epoch 1/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.6514935697202773
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.6514935697202773
#
# 526/526 [==============================] - 15s 9ms/step - loss: 4.7664e-05 - accuracy: 0.6273 - val_loss: 0.6310 - val_accuracy: 0.5468
# Epoch 2/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8439379853628179
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8439379853628179
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.7835e-05 - accuracy: 0.6985 - val_loss: 0.4085 - val_accuracy: 0.8313
# Epoch 3/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.845796126084965
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.845796126084965
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.4903e-05 - accuracy: 0.7349 - val_loss: 0.2221 - val_accuracy: 0.9496
# Epoch 4/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8903615948906463
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8903615948906463
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.3031e-05 - accuracy: 0.7678 - val_loss: 0.2774 - val_accuracy: 0.9026
# Epoch 5/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.833328667858608
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.1795e-05 - accuracy: 0.7616 - val_loss: 0.1806 - val_accuracy: 0.9523
# Epoch 6/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8369811548815411
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.7992e-05 - accuracy: 0.8016 - val_loss: 0.1704 - val_accuracy: 0.9475
# Epoch 7/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8241780762529806
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.7928e-05 - accuracy: 0.8044 - val_loss: 0.1111 - val_accuracy: 0.9691
# Epoch 8/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8260236938127419
#
# 526/526 [==============================] - 5s 10ms/step - loss: 2.7180e-05 - accuracy: 0.8153 - val_loss: 0.1205 - val_accuracy: 0.9619
# Epoch 9/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8509586102654558
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.7483e-05 - accuracy: 0.8116 - val_loss: 0.1294 - val_accuracy: 0.9565
# Epoch 10/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8629098200737639
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.6007e-05 - accuracy: 0.8222 - val_loss: 0.1399 - val_accuracy: 0.9530
# Epoch 11/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8203062131176124
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.4324e-05 - accuracy: 0.8307 - val_loss: 0.1038 - val_accuracy: 0.9640
# Epoch 12/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8283855597905523
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.3178e-05 - accuracy: 0.8473 - val_loss: 0.1264 - val_accuracy: 0.9554
# Epoch 13/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.842659887480081
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.4683e-05 - accuracy: 0.8306 - val_loss: 0.1319 - val_accuracy: 0.9551
# Epoch 14/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8286049359029872
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.1190e-05 - accuracy: 0.8530 - val_loss: 0.0973 - val_accuracy: 0.9654
# Epoch 15/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8166537260946793
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.1261e-05 - accuracy: 0.8536 - val_loss: 0.0870 - val_accuracy: 0.9688
# Epoch 16/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8504423618474068
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.1753e-05 - accuracy: 0.8547 - val_loss: 0.1175 - val_accuracy: 0.9558
# Epoch 17/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8416273906439828
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.1427e-05 - accuracy: 0.8594 - val_loss: 0.1152 - val_accuracy: 0.9537
# Epoch 18/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.848635492384235
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.8630e-05 - accuracy: 0.8704 - val_loss: 0.1143 - val_accuracy: 0.9534
# Epoch 19/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8259849457161523
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.8067e-05 - accuracy: 0.8797 - val_loss: 0.0775 - val_accuracy: 0.9715
# Epoch 20/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8176862229307775
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.7188e-05 - accuracy: 0.8873 - val_loss: 0.0817 - val_accuracy: 0.9702
# Epoch 21/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.854314224982775
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.8919e-05 - accuracy: 0.8784 - val_loss: 0.1015 - val_accuracy: 0.9609
# Epoch 22/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8327736713439695
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.7629e-05 - accuracy: 0.8799 - val_loss: 0.0985 - val_accuracy: 0.9613
# Epoch 23/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8286049359029872
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.6886e-05 - accuracy: 0.8830 - val_loss: 0.0873 - val_accuracy: 0.9654
# Epoch 24/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8402980215022706
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.6042e-05 - accuracy: 0.8959 - val_loss: 0.0931 - val_accuracy: 0.9616
# Epoch 25/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8512167344744805
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.5647e-05 - accuracy: 0.8956 - val_loss: 0.1029 - val_accuracy: 0.9568
# Epoch 26/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8156212292585812
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.4882e-05 - accuracy: 0.9003 - val_loss: 0.0820 - val_accuracy: 0.9674
# Epoch 27/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8332511716654292
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.5538e-05 - accuracy: 0.8981 - val_loss: 0.0770 - val_accuracy: 0.9715
# Epoch 28/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8382330278300744
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.4368e-05 - accuracy: 0.9083 - val_loss: 0.0977 - val_accuracy: 0.9589
# Epoch 29/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8476417436447263
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.5812e-05 - accuracy: 0.8934 - val_loss: 0.1435 - val_accuracy: 0.9424
# Epoch 30/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8265786903273804
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.4707e-05 - accuracy: 0.9037 - val_loss: 0.1209 - val_accuracy: 0.9530
# Epoch 31/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8255074453946927
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.4579e-05 - accuracy: 0.9040 - val_loss: 0.1049 - val_accuracy: 0.9613
# Epoch 32/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8018631499871014
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.2555e-05 - accuracy: 0.9207 - val_loss: 0.0919 - val_accuracy: 0.9685
# Epoch 33/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8130399871683358
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.1527e-05 - accuracy: 0.9260 - val_loss: 0.0975 - val_accuracy: 0.9640
# Epoch 34/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8215968341627351
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.3414e-05 - accuracy: 0.9104 - val_loss: 0.0856 - val_accuracy: 0.9657
# Epoch 35/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8013469015690523
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.2155e-05 - accuracy: 0.9218 - val_loss: 0.0906 - val_accuracy: 0.9678
# Epoch 36/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.793306302992702
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.1560e-05 - accuracy: 0.9208 - val_loss: 0.0881 - val_accuracy: 0.9667
# Epoch 37/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8259849457161523
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.1457e-05 - accuracy: 0.9260 - val_loss: 0.0841 - val_accuracy: 0.9715
# Epoch 38/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7912025612239162
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.0202e-05 - accuracy: 0.9287 - val_loss: 0.0793 - val_accuracy: 0.9736
# Epoch 39/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8205643373266369
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.1316e-05 - accuracy: 0.9293 - val_loss: 0.1032 - val_accuracy: 0.9643
# Epoch 40/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8384524039425094
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.2032e-05 - accuracy: 0.9275 - val_loss: 0.0903 - val_accuracy: 0.9688
# Epoch 41/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.829676180835675
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.0670e-05 - accuracy: 0.9259 - val_loss: 0.1098 - val_accuracy: 0.9571
# Epoch 42/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.808316255212715
#
# 526/526 [==============================] - 4s 7ms/step - loss: 8.8399e-06 - accuracy: 0.9420 - val_loss: 0.0738 - val_accuracy: 0.9770
# Epoch 43/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8036700194502733
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.0698e-05 - accuracy: 0.9324 - val_loss: 0.0903 - val_accuracy: 0.9709
# Epoch 44/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8246943246710297
#
# 526/526 [==============================] - 4s 7ms/step - loss: 9.3851e-06 - accuracy: 0.9362 - val_loss: 0.0918 - val_accuracy: 0.9698
# Epoch 45/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8174280987217529
#
# 526/526 [==============================] - 4s 7ms/step - loss: 9.6824e-06 - accuracy: 0.9339 - val_loss: 0.0839 - val_accuracy: 0.9698
# Epoch 46/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8005337808453892
#
# 526/526 [==============================] - 4s 7ms/step - loss: 9.1576e-06 - accuracy: 0.9411 - val_loss: 0.0766 - val_accuracy: 0.9763
# Epoch 47/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8078387548912553
#
# 526/526 [==============================] - 4s 7ms/step - loss: 8.4627e-06 - accuracy: 0.9465 - val_loss: 0.0987 - val_accuracy: 0.9667
# Epoch 48/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8361292860612886
#
# 526/526 [==============================] - 4s 7ms/step - loss: 8.2442e-06 - accuracy: 0.9489 - val_loss: 0.1017 - val_accuracy: 0.9657
# Epoch 49/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8181637232522372
#
# 526/526 [==============================] - 4s 7ms/step - loss: 7.3475e-06 - accuracy: 0.9550 - val_loss: 0.0734 - val_accuracy: 0.9805
# Epoch 50/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8267205702466365
#
# 526/526 [==============================] - 4s 7ms/step - loss: 6.9763e-06 - accuracy: 0.9559 - val_loss: 0.0731 - val_accuracy: 0.9822
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ = 0.8903615948906463

# %% [markdown]
# АРХИТЕКТУРА МОДЕЛИ

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ГРАФИКИ ОБУЧЕНИЯ

# %%
# графики обучения
def cm_to_inch(value):
    return value/2.54

plt.figure(figsize=(cm_to_inch(30),cm_to_inch(15)))

plt.title('Графики обучения прогнозирования параметра "Снег"', 
          pad=30, fontsize=16)

plt.plot(history.history['accuracy'], 
         label='Точность Accuracy на обучающем наборе', linewidth=3)
plt.plot(history.history['val_accuracy'], 
         label='Точность Accuracy на проверочном наборе', linewidth=3)
plt.plot(cb.get_recall_list(), 
         label='Точность Recall на проверочном наборе', linewidth=3)
plt.plot(cb.get_general_list(), 
         label='Точность (Recall+Accuracy)/2 на проверочном наборе', linewidth=3)

plt.xlabel('Эпоха обучения', fontsize=14)
plt.ylabel('Точность', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)
plt.grid(True)
plt.show()
