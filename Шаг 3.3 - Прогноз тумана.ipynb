# %%
# библиотеки....
import numpy as np 
import pandas as pd 
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Reshape, concatenate,  Flatten
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, SpatialDropout1D, MaxPooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import Callback
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, accuracy_score 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ЧТЕНИЕ И НОРМИРОВАНИЕ ДАННЫХ ИСХОДНОЙ ТАБЛИЦЫ

# %%
df = pd.read_csv('/content/drive/My Drive/Bases/makhachkala_weather_2011_2020_2.csv')

# %%
# нормируем столбцы (6 столбцов), которые по условию задачи
# участвуют в формировании вектора X
x_cols = ['t_air', 'rel_hum', 'P_atm', 'precip', 'wind_dir', 'wind_speed']

# нормировка данных по каждому столбцу к интервалу [0..1]
for col in x_cols:
  m = max(df[col])
  df[col] = df[col] / m

df
# Out:
#                   datetime     t_air  t_soil  t_dew  P_part_water  rel_hum  \
# 0      2011-01-01 00:00:00  0.170984     7.0    5.5          9.01     0.93
# 1      2011-01-01 03:00:00  0.160622     6.0    5.1          8.75     0.92
# 2      2011-01-01 06:00:00  0.150259     6.0    4.9          8.64     0.94
# 3      2011-01-01 09:00:00  0.152850     7.0    3.8          8.00     0.86
# 4      2011-01-01 12:00:00  0.134715     6.0    3.0          7.58     0.86
# ...                    ...       ...     ...    ...           ...      ...
# 29219  2020-12-31 09:00:00  0.111399     6.0    1.8          7.01     0.84
# 29220  2020-12-31 12:00:00  0.121762     6.0    2.4          7.29     0.85
# 29221  2020-12-31 15:00:00  0.113990     5.0    2.0          7.09     0.85
# 29222  2020-12-31 18:00:00  0.119171     2.0    2.0          7.07     0.83
# 29223  2020-12-31 21:00:00  0.098446     4.0    1.7          6.93     0.86
#
#        satur_def     P_atm  precip  wind_dir  wind_speed  shower  snow  fog  \
# 0           0.73  0.970389     0.0  0.833333      0.1875       0     0    0
# 1           0.73  0.969437     0.0  0.861111      0.2500       0     0    0
# 2           0.58  0.969723     0.0  0.916667      0.1875       0     0    0
# 3           1.28  0.969628     0.0  0.861111      0.3750       0     0    0
# 4           1.26  0.970199     0.0  0.888889      0.3750       0     0    0
# ...          ...       ...     ...       ...         ...     ...   ...  ...
# 29219       1.33  0.977625     0.0  0.886111      0.1875       0     0    0
# 29220       1.29  0.976959     0.0  0.802778      0.1250       0     0    0
# 29221       1.25  0.976673     0.0  0.905556      0.0625       0     0    1
# 29222       1.45  0.980577     0.0  0.433333      0.1875       0     0    0
# 29223       1.13  0.979625     0.0  0.363889      0.1875       0     0    0
#
#        strong_wind
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 29219            0
# 29220            0
# 29221            0
# 29222            0
# 29223            0
#
# [29224 rows x 15 columns]

# %% [markdown]
# ФУНКЦИЯ ГЕНЕРАЦИИ ВЫБОРКИ

# %%
# data - исходный датафрейм
# days_count - размер блока данных для X примера (по умолчанию 1 день)
# x_col_names - список колонок c которых генерируются векторы X
# y_col_name - колонка для генерации значений Y

def CreateSamples(data, x_col_names, y_col_name, days_count=1):
  
  block_size = days_count * 8 # размер блока данных

  pos = 0 # начальная позиция текущего смещения в датасете

  # обнуляем списки...
  samples_x = []
  samples_y = []
  
  Ex = False

  while not Ex: # цикл остановится, когда переменная Ex станет истиной 

    if pos + block_size < data.shape[0]: # если не дошли до конца....

      x_vec = []
      for x_col_name in x_col_names:
        x_vec.extend(data[x_col_name][pos:pos+block_size].to_list())
      
      y_vec = data[y_col_name][pos+block_size:pos+block_size+1].to_list()   

      samples_x.append(x_vec)
      samples_y.append(y_vec)

    else:

      Ex = True
    
    pos += 1 # сдвигаем позицию на 1

  # перевод данных в numpy массивы
  samples_x = np.array(samples_x)
  samples_y = np.array(samples_y).astype('float')

  return samples_x, samples_y

# %% [markdown]
# ГЕНЕРАЦИЯ ВЫБОРКИ

# %%
# размер блока данных
days_count = 7

# генерация выборки 
samples_x, samples_y = CreateSamples(df, x_cols, 'fog', days_count)

# рамерность массивов
print(samples_x.shape)
print(samples_y.shape)
# Out:
# (29168, 336)
# (29168, 1)

# %% [markdown]
# МОДЕЛЬ НЕЙРОННОЙ СЕТИ
#
# Данные по 6 парамертам разделяются на 6 паралелльных веток для обработки одномерной сверткой, далее они объединяются и проходят через каскад полносвязных слоев.

# %%
# days_count - размер блока данных в днях

def CreateModel(days_count, activation='linear', dropout=0.1):

  input = Input((days_count*8*6,))
  
  x = Reshape((days_count*8*6, 1))(input)

  # свертка 1-го параметра
  x1 = SpatialDropout1D(dropout)(x[:, days_count*8*0:days_count*8*1, :])
  x1 = Conv1D(20, 7, activation=activation)(x1)
  x1 = MaxPooling1D(2)(x1)
  x1 = Flatten()(x1)

  # свертка 2-го параметра
  x2 = SpatialDropout1D(dropout)(x[:, days_count*8*1:days_count*8*2, :])
  x2 = Conv1D(20, 7, activation=activation)(x2)
  x2 = MaxPooling1D(2)(x2)
  x2 = Flatten()(x2)

  # свертка 3-го параметра
  x3 = SpatialDropout1D(dropout)(x[:, days_count*8*2:days_count*8*3, :])
  x3 = Conv1D(20, 7, activation=activation)(x3)
  x3 = MaxPooling1D(2)(x3)
  x3 = Flatten()(x3)
  
  # свертка 4-го параметра
  x4 = SpatialDropout1D(dropout)(x[:, days_count*8*3:days_count*8*4, :])
  x4 = Conv1D(20, 7, activation=activation)(x4)
  x4 = MaxPooling1D(2)(x4)
  x4 = Flatten()(x4)

  # свертка 5-го параметра
  x5 = SpatialDropout1D(dropout)(x[:, days_count*8*4:days_count*8*5, :])
  x5 = Conv1D(20, 7, activation=activation)(x5)
  x5 = MaxPooling1D(2)(x5)
  x5 = Flatten()(x5)

  # свертка 6-го параметра
  x6 = SpatialDropout1D(dropout)(x[:, days_count*8*5:days_count*8*6, :])
  x6 = Conv1D(20, 7, activation=activation)(x6)
  x6 = MaxPooling1D(2)(x6)
  x6 = Flatten()(x6)

  # оббъединяем результаты свертки в 1 слой
  x = concatenate([x1, x2, x3, x4, x5, x6])

  x = BatchNormalization()(x)
  x = Dense(500, activation=activation)(x)
  x = Dropout(dropout)(x)
  
  x = BatchNormalization()(x)
  x = Dense(200, activation=activation)(x)
  x = Dropout(dropout)(x)

  output = Dense(1, activation='sigmoid')(x) 

  return Model(input, output)

# %% [markdown]
# CALLBACK для фиксации лучшего обучения по метрике RECALL

# %%
# файл для сохранения лучших весов модели
model_save_file = '/content/drive/My Drive/Bases/model_best_f.h5'

# собственный коллбэк
class MyCallback(Callback):
  
  # инициализация
  def __init__(self, model, x_val, y_val):
    # модель
    self.model = model 
    # проверочная выборка
    self.x_val = x_val 
    self.y_val = y_val
    # начальный счет по средней метрике
    self.score = 0
    # список значений по метрике Recall
    self.recall_list = []
    # список значений по средней метрике
    self.general_list = []
       
  # подсчет метрики Recall для val  
  def calc_metric(self):
    y_pred = self.model.predict(self.x_val)
    y_p = np.around(y_pred).astype(int)
    y_t = np.around(self.y_val).astype(int)
    rec = recall_score(y_t, y_p, average='macro')
    acc = accuracy_score(y_t, y_p)
    return rec, acc
  
  # окончение каждой эпохи....
  def on_epoch_end(self, epoch, logs=None):
    rec, acc = self.calc_metric()
    self.recall_list.append(rec)
    score_0 = (rec + acc)/2
    self.general_list.append(score_0)
    print('\n\nТекущая точность (Recall+Accuracy)/2 =', score_0, '\n')
    if score_0 > self.score:
      self.score = score_0
      print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 =', score_0, '\n')
      self.model.save_weights(model_save_file)   

  # в конце обучения
  def on_train_end(self, logs=None):
    print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ =', self.score, '\n')
  
  # получение списка recall_list
  def get_recall_list(self):
    return self.recall_list

  # получение списка general_list
  def get_general_list(self):
    return self.general_list

# %% [markdown]
# ПАРАМЕТРЫ ОБУЧЕНИЯ

# %%
# параметры обучения

batch_size = 50

dropout = 0.25

activate_function = 'relu'

epochs_count = 50

learning_rate = 1e-4

# %% [markdown]
# ОБУЧЕНИЕ НЕЙРОННОЙ СЕТИ

# %%
# деление выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(samples_x, samples_y, 
                                                  test_size=0.1, random_state=1)

# %%
# настройка весов для классов модели (учет разбаллансировки)
weight_for_0 = 1.0 / (y_train == 0.0).sum()
weight_for_1 = 1.0 / (y_train == 1.0).sum()

class_weight = {0: weight_for_0, 1: weight_for_1}

print(class_weight)
# Out:
# {0: 3.852080123266564e-05, 1: 0.003436426116838488}

# %%
# создание модели
model = CreateModel(days_count=days_count, 
                    activation=activate_function, dropout=dropout)  
cb = MyCallback(model, x_val, y_val)

# %%
# компиляция
model.compile(optimizer=Adam(learning_rate=learning_rate), 
              loss=['binary_crossentropy'], 
              metrics=['accuracy'])

# обучение
history = model.fit(x_train, y_train, 
                    batch_size = batch_size,
                    epochs= epochs_count, 
                    validation_data=(x_val, y_val), 
                    verbose=1, 
                    class_weight = class_weight,
                    callbacks=[cb])
# Out:
# Epoch 1/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.5269881236700308
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.5269881236700308
#
# 526/526 [==============================] - 14s 9ms/step - loss: 5.7663e-05 - accuracy: 0.5765 - val_loss: 0.9399 - val_accuracy: 0.3723
# Epoch 2/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.5953433286611366
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.5953433286611366
#
# 526/526 [==============================] - 4s 7ms/step - loss: 5.0184e-05 - accuracy: 0.6224 - val_loss: 0.7393 - val_accuracy: 0.5348
# Epoch 3/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.5757272070681321
#
# 526/526 [==============================] - 4s 8ms/step - loss: 4.6125e-05 - accuracy: 0.6650 - val_loss: 0.8271 - val_accuracy: 0.4769
# Epoch 4/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.6150457325722408
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.6150457325722408
#
# 526/526 [==============================] - 6s 12ms/step - loss: 4.3795e-05 - accuracy: 0.6734 - val_loss: 0.7185 - val_accuracy: 0.5530
# Epoch 5/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.5930009524452675
#
# 526/526 [==============================] - 4s 8ms/step - loss: 4.1357e-05 - accuracy: 0.7016 - val_loss: 0.7547 - val_accuracy: 0.5636
# Epoch 6/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.6564998637403548
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.6564998637403548
#
# 526/526 [==============================] - 5s 9ms/step - loss: 3.8246e-05 - accuracy: 0.7118 - val_loss: 0.6527 - val_accuracy: 0.6239
# Epoch 7/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.6830910375785308
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.6830910375785308
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.8053e-05 - accuracy: 0.7164 - val_loss: 0.5463 - val_accuracy: 0.6911
# Epoch 8/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7022252062364795
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.7022252062364795
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.6793e-05 - accuracy: 0.7299 - val_loss: 0.5393 - val_accuracy: 0.6846
# Epoch 9/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.691168354414349
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.4608e-05 - accuracy: 0.7473 - val_loss: 0.5463 - val_accuracy: 0.6939
# Epoch 10/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7004684240745779
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.2197e-05 - accuracy: 0.7577 - val_loss: 0.5278 - val_accuracy: 0.7062
# Epoch 11/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7533408717661143
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.7533408717661143
#
# 526/526 [==============================] - 5s 10ms/step - loss: 2.9890e-05 - accuracy: 0.7804 - val_loss: 0.3753 - val_accuracy: 0.8162
# Epoch 12/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7089934879297877
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.0639e-05 - accuracy: 0.7800 - val_loss: 0.5108 - val_accuracy: 0.7175
# Epoch 13/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7513431131366846
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.8068e-05 - accuracy: 0.7865 - val_loss: 0.3807 - val_accuracy: 0.8056
# Epoch 14/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7467446430230462
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.9246e-05 - accuracy: 0.7919 - val_loss: 0.3566 - val_accuracy: 0.8234
# Epoch 15/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7669121527543538
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.7669121527543538
#
# 526/526 [==============================] - 5s 10ms/step - loss: 2.4361e-05 - accuracy: 0.8209 - val_loss: 0.3765 - val_accuracy: 0.8183
# Epoch 16/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7641909530363811
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.8451e-05 - accuracy: 0.8081 - val_loss: 0.3393 - val_accuracy: 0.8306
# Epoch 17/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7682206762109045
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.7682206762109045
#
# 526/526 [==============================] - 5s 9ms/step - loss: 2.2736e-05 - accuracy: 0.8309 - val_loss: 0.2342 - val_accuracy: 0.9078
# Epoch 18/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7199982633494826
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.3146e-05 - accuracy: 0.8367 - val_loss: 0.3952 - val_accuracy: 0.8039
# Epoch 19/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7584212948148082
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.2753e-05 - accuracy: 0.8372 - val_loss: 0.3109 - val_accuracy: 0.8629
# Epoch 20/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7552697068782559
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.0329e-05 - accuracy: 0.8592 - val_loss: 0.3524 - val_accuracy: 0.8348
# Epoch 21/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7702873583576221
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.7702873583576221
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.9415e-05 - accuracy: 0.8587 - val_loss: 0.2198 - val_accuracy: 0.9105
# Epoch 22/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7824638335712111
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.7824638335712111
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.9341e-05 - accuracy: 0.8823 - val_loss: 0.3025 - val_accuracy: 0.8629
# Epoch 23/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8113800248244444
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8113800248244444
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.6614e-05 - accuracy: 0.8801 - val_loss: 0.1854 - val_accuracy: 0.9332
# Epoch 24/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7938647912938215
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.6143e-05 - accuracy: 0.8912 - val_loss: 0.1782 - val_accuracy: 0.9338
# Epoch 25/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7911435915758489
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.7233e-05 - accuracy: 0.8840 - val_loss: 0.1588 - val_accuracy: 0.9462
# Epoch 26/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7840306922961016
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.5907e-05 - accuracy: 0.8901 - val_loss: 0.1417 - val_accuracy: 0.9527
# Epoch 27/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7925041914348352
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.4935e-05 - accuracy: 0.9045 - val_loss: 0.1736 - val_accuracy: 0.9400
# Epoch 28/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8004436612360777
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3681e-05 - accuracy: 0.9060 - val_loss: 0.1368 - val_accuracy: 0.9585
# Epoch 29/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.819078518158159
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.819078518158159
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.4179e-05 - accuracy: 0.9053 - val_loss: 0.2055 - val_accuracy: 0.9194
# Epoch 30/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8060754724230748
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.4597e-05 - accuracy: 0.8999 - val_loss: 0.1682 - val_accuracy: 0.9421
# Epoch 31/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7958625499232512
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3411e-05 - accuracy: 0.9140 - val_loss: 0.1575 - val_accuracy: 0.9445
# Epoch 32/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7900586857860141
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3923e-05 - accuracy: 0.9115 - val_loss: 0.2041 - val_accuracy: 0.9208
# Epoch 33/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7952080323519961
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.1614e-05 - accuracy: 0.9258 - val_loss: 0.1319 - val_accuracy: 0.9595
# Epoch 34/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7743344403329573
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.0635e-05 - accuracy: 0.9286 - val_loss: 0.1359 - val_accuracy: 0.9558
# Epoch 35/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8020110316469277
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2314e-05 - accuracy: 0.9280 - val_loss: 0.1915 - val_accuracy: 0.9287
# Epoch 36/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8126027776488549
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.1245e-05 - accuracy: 0.9250 - val_loss: 0.1591 - val_accuracy: 0.9427
# Epoch 37/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7783988811091045
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2927e-05 - accuracy: 0.9203 - val_loss: 0.1062 - val_accuracy: 0.9691
# Epoch 38/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7701321525222344
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3031e-05 - accuracy: 0.9230 - val_loss: 0.1332 - val_accuracy: 0.9582
# Epoch 39/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7923663444002595
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.0090e-05 - accuracy: 0.9357 - val_loss: 0.1404 - val_accuracy: 0.9558
# Epoch 40/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7782094693580526
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.0264e-05 - accuracy: 0.9344 - val_loss: 0.1226 - val_accuracy: 0.9609
# Epoch 41/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7853223686377999
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.0387e-05 - accuracy: 0.9334 - val_loss: 0.1393 - val_accuracy: 0.9544
# Epoch 42/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7887496506435039
#
# 526/526 [==============================] - 4s 8ms/step - loss: 9.9203e-06 - accuracy: 0.9418 - val_loss: 0.1458 - val_accuracy: 0.9510
# Epoch 43/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7556480186944
#
# 526/526 [==============================] - 4s 8ms/step - loss: 8.8414e-06 - accuracy: 0.9409 - val_loss: 0.1016 - val_accuracy: 0.9709
# Epoch 44/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7436267493161985
#
# 526/526 [==============================] - 4s 8ms/step - loss: 8.9789e-06 - accuracy: 0.9410 - val_loss: 0.0996 - val_accuracy: 0.9709
# Epoch 45/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7621753239201801
#
# 526/526 [==============================] - 4s 8ms/step - loss: 8.1110e-06 - accuracy: 0.9465 - val_loss: 0.1030 - val_accuracy: 0.9715
# Epoch 46/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.757266953821726
#
# 526/526 [==============================] - 4s 8ms/step - loss: 9.6655e-06 - accuracy: 0.9405 - val_loss: 0.1159 - val_accuracy: 0.9650
# Epoch 47/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7648276001208649
#
# 526/526 [==============================] - 4s 8ms/step - loss: 7.7818e-06 - accuracy: 0.9497 - val_loss: 0.1152 - val_accuracy: 0.9671
# Epoch 48/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7599192300224107
#
# 526/526 [==============================] - 4s 7ms/step - loss: 8.6566e-06 - accuracy: 0.9490 - val_loss: 0.1196 - val_accuracy: 0.9606
# Epoch 49/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7612798298813972
#
# 526/526 [==============================] - 4s 8ms/step - loss: 8.6539e-06 - accuracy: 0.9522 - val_loss: 0.1319 - val_accuracy: 0.9544
# Epoch 50/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7590753007001039
#
# 526/526 [==============================] - 4s 7ms/step - loss: 9.2443e-06 - accuracy: 0.9401 - val_loss: 0.1094 - val_accuracy: 0.9674
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ = 0.819078518158159

# %% [markdown]
# АРХИТЕКТУРА МОДЕЛИ

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ГРАФИКИ ОБУЧЕНИЯ

# %%
# графики обучения
def cm_to_inch(value):
    return value/2.54

plt.figure(figsize=(cm_to_inch(30),cm_to_inch(15)))

plt.title('Графики обучения прогнозирования параметра "Туман"', 
          pad=30, fontsize=16)

plt.plot(history.history['accuracy'], 
         label='Точность Accuracy на обучающем наборе', linewidth=3)
plt.plot(history.history['val_accuracy'], 
         label='Точность Accuracy на проверочном наборе', linewidth=3)
plt.plot(cb.get_recall_list(), 
         label='Точность Recall на проверочном наборе', linewidth=3)
plt.plot(cb.get_general_list(), 
         label='Точность (Recall+Accuracy)/2 на проверочном наборе', linewidth=3)

plt.xlabel('Эпоха обучения', fontsize=14)
plt.ylabel('Точность', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)
plt.grid(True)
plt.show()
