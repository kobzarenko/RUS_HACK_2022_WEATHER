# %%
# библиотеки....
import numpy as np 
import pandas as pd 
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Reshape, concatenate,  Flatten
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, SpatialDropout1D, MaxPooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import Callback
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, accuracy_score 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ЧТЕНИЕ И НОРМИРОВАНИЕ ДАННЫХ ИСХОДНОЙ ТАБЛИЦЫ

# %%
df = pd.read_csv('/content/drive/My Drive/Bases/makhachkala_weather_2011_2020_2.csv')

# %%
# нормируем столбцы (6 столбцов), которые по условию задачи
# участвуют в формировании вектора X
x_cols = ['t_air', 'rel_hum', 'P_atm', 'precip', 'wind_dir', 'wind_speed']

# нормировка данных по каждому столбцу к интервалу [0..1]
for col in x_cols:
  m = max(df[col])
  df[col] = df[col] / m

df
# Out:
#                   datetime     t_air  t_soil  t_dew  P_part_water  rel_hum  \
# 0      2011-01-01 00:00:00  0.170984     7.0    5.5          9.01     0.93
# 1      2011-01-01 03:00:00  0.160622     6.0    5.1          8.75     0.92
# 2      2011-01-01 06:00:00  0.150259     6.0    4.9          8.64     0.94
# 3      2011-01-01 09:00:00  0.152850     7.0    3.8          8.00     0.86
# 4      2011-01-01 12:00:00  0.134715     6.0    3.0          7.58     0.86
# ...                    ...       ...     ...    ...           ...      ...
# 29219  2020-12-31 09:00:00  0.111399     6.0    1.8          7.01     0.84
# 29220  2020-12-31 12:00:00  0.121762     6.0    2.4          7.29     0.85
# 29221  2020-12-31 15:00:00  0.113990     5.0    2.0          7.09     0.85
# 29222  2020-12-31 18:00:00  0.119171     2.0    2.0          7.07     0.83
# 29223  2020-12-31 21:00:00  0.098446     4.0    1.7          6.93     0.86
#
#        satur_def     P_atm  precip  wind_dir  wind_speed  shower  snow  fog  \
# 0           0.73  0.970389     0.0  0.833333      0.1875       0     0    0
# 1           0.73  0.969437     0.0  0.861111      0.2500       0     0    0
# 2           0.58  0.969723     0.0  0.916667      0.1875       0     0    0
# 3           1.28  0.969628     0.0  0.861111      0.3750       0     0    0
# 4           1.26  0.970199     0.0  0.888889      0.3750       0     0    0
# ...          ...       ...     ...       ...         ...     ...   ...  ...
# 29219       1.33  0.977625     0.0  0.886111      0.1875       0     0    0
# 29220       1.29  0.976959     0.0  0.802778      0.1250       0     0    0
# 29221       1.25  0.976673     0.0  0.905556      0.0625       0     0    1
# 29222       1.45  0.980577     0.0  0.433333      0.1875       0     0    0
# 29223       1.13  0.979625     0.0  0.363889      0.1875       0     0    0
#
#        strong_wind
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 29219            0
# 29220            0
# 29221            0
# 29222            0
# 29223            0
#
# [29224 rows x 15 columns]

# %% [markdown]
# ФУНКЦИЯ ГЕНЕРАЦИИ ВЫБОРКИ

# %%
# data - исходный датафрейм
# days_count - размер блока данных для X примера (по умолчанию 1 день)
# x_col_names - список колонок c которых генерируются векторы X
# y_col_name - колонка для генерации значений Y

def CreateSamples(data, x_col_names, y_col_name, days_count=1):
  
  block_size = days_count * 8 # размер блока данных

  pos = 0 # начальная позиция текущего смещения в датасете

  # обнуляем списки...
  samples_x = []
  samples_y = []
  
  Ex = False

  while not Ex: # цикл остановится, когда переменная Ex станет истиной 

    if pos + block_size < data.shape[0]: # если не дошли до конца....

      x_vec = []
      for x_col_name in x_col_names:
        x_vec.extend(data[x_col_name][pos:pos+block_size].to_list())
      
      y_vec = data[y_col_name][pos+block_size:pos+block_size+1].to_list()   

      samples_x.append(x_vec)
      samples_y.append(y_vec)

    else:

      Ex = True
    
    pos += 1 # сдвигаем позицию на 1

  # перевод данных в numpy массивы
  samples_x = np.array(samples_x)
  samples_y = np.array(samples_y).astype('float')

  return samples_x, samples_y

# %% [markdown]
# ГЕНЕРАЦИЯ ВЫБОРКИ

# %%
# размер блока данных
days_count = 12

# генерация выборки 
samples_x, samples_y = CreateSamples(df, x_cols, 'shower', days_count)

# рамерность массивов
print(samples_x.shape)
print(samples_y.shape)
# Out:
# (29128, 576)
# (29128, 1)

# %% [markdown]
# МОДЕЛЬ НЕЙРОННОЙ СЕТИ
#
# Данные по 6 парамертам разделяются на 6 паралелльных веток для обработки одномерной сверткой, далее они объединяются и проходят через каскад полносвязных слоев.

# %%
# days_count - размер блока данных в днях

def CreateModel(days_count, activation='linear', dropout=0.1):

  input = Input((days_count*8*6,))
  
  x = Reshape((days_count*8*6, 1))(input)

  # свертка 1-го параметра
  x1 = SpatialDropout1D(dropout)(x[:, days_count*8*0:days_count*8*1, :])
  x1 = Conv1D(20, 7, activation=activation)(x1)
  x1 = MaxPooling1D(2)(x1)
  x1 = Flatten()(x1)

  # свертка 2-го параметра
  x2 = SpatialDropout1D(dropout)(x[:, days_count*8*1:days_count*8*2, :])
  x2 = Conv1D(20, 7, activation=activation)(x2)
  x2 = MaxPooling1D(2)(x2)
  x2 = Flatten()(x2)

  # свертка 3-го параметра
  x3 = SpatialDropout1D(dropout)(x[:, days_count*8*2:days_count*8*3, :])
  x3 = Conv1D(20, 7, activation=activation)(x3)
  x3 = MaxPooling1D(2)(x3)
  x3 = Flatten()(x3)
  
  # свертка 4-го параметра
  x4 = SpatialDropout1D(dropout)(x[:, days_count*8*3:days_count*8*4, :])
  x4 = Conv1D(20, 7, activation=activation)(x4)
  x4 = MaxPooling1D(2)(x4)
  x4 = Flatten()(x4)

  # свертка 5-го параметра
  x5 = SpatialDropout1D(dropout)(x[:, days_count*8*4:days_count*8*5, :])
  x5 = Conv1D(20, 7, activation=activation)(x5)
  x5 = MaxPooling1D(2)(x5)
  x5 = Flatten()(x5)

  # свертка 6-го параметра
  x6 = SpatialDropout1D(dropout)(x[:, days_count*8*5:days_count*8*6, :])
  x6 = Conv1D(20, 7, activation=activation)(x6)
  x6 = MaxPooling1D(2)(x6)
  x6 = Flatten()(x6)

  # оббъединяем результаты свертки в 1 слой
  x = concatenate([x1, x2, x3, x4, x5, x6])

  x = BatchNormalization()(x)
  x = Dense(500, activation=activation)(x)
  x = Dropout(dropout)(x)
  
  x = BatchNormalization()(x)
  x = Dense(200, activation=activation)(x)
  x = Dropout(dropout)(x)

  output = Dense(1, activation='sigmoid')(x) 

  return Model(input, output)

# %% [markdown]
# CALLBACK для фиксации лучшего обучения по метрике RECALL

# %%
# файл для сохранения лучших весов модели
model_save_file = '/content/drive/My Drive/Bases/model_best_sh.h5'

# собственный коллбэк
class MyCallback(Callback):
  
  # инициализация
  def __init__(self, model, x_val, y_val):
    # модель
    self.model = model 
    # проверочная выборка
    self.x_val = x_val 
    self.y_val = y_val
    # начальный счет по средней метрике
    self.score = 0
    # список значений по метрике Recall
    self.recall_list = []
    # список значений по средней метрике
    self.general_list = []
       
  # подсчет метрики Recall для val  
  def calc_metric(self):
    y_pred = self.model.predict(self.x_val)
    y_p = np.around(y_pred).astype(int)
    y_t = np.around(self.y_val).astype(int)
    rec = recall_score(y_t, y_p, average='macro')
    acc = accuracy_score(y_t, y_p)
    return rec, acc
  
  # окончение каждой эпохи....
  def on_epoch_end(self, epoch, logs=None):
    rec, acc = self.calc_metric()
    self.recall_list.append(rec)
    score_0 = (rec + acc)/2
    self.general_list.append(score_0)
    print('\n\nТекущая точность (Recall+Accuracy)/2 =', score_0, '\n')
    if score_0 > self.score:
      self.score = score_0
      print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 =', score_0, '\n')
      self.model.save_weights(model_save_file)   

  # в конце обучения
  def on_train_end(self, logs=None):
    print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ =', self.score, '\n')
  
  # получение списка recall_list
  def get_recall_list(self):
    return self.recall_list

  # получение списка general_list
  def get_general_list(self):
    return self.general_list

# %% [markdown]
# ПАРАМЕТРЫ ОБУЧЕНИЯ

# %%
# параметры обучения

batch_size = 50

dropout = 0.25

activate_function = 'relu'

epochs_count = 50

learning_rate = 1e-4

# %% [markdown]
# ОБУЧЕНИЕ НЕЙРОННОЙ СЕТИ

# %%
# деление выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(samples_x, samples_y, 
                                                  test_size=0.1, random_state=1)

# %%
# настройка весов для классов модели (учет разбаллансировки)
weight_for_0 = 1.0 / (y_train == 0.0).sum()
weight_for_1 = 1.0 / (y_train == 1.0).sum()

class_weight = {0: weight_for_0, 1: weight_for_1}

print(class_weight)
# Out:
# {0: 3.950383187169155e-05, 1: 0.0011098779134295228}

# %%
# создание модели
model = CreateModel(days_count=days_count, 
                    activation=activate_function, dropout=dropout)  
cb = MyCallback(model, x_val, y_val)

# %%
# компиляция
model.compile(optimizer=Adam(learning_rate=learning_rate), 
              loss=['binary_crossentropy'], 
              metrics=['accuracy'])

# обучение
history = model.fit(x_train, y_train, 
                    batch_size = batch_size,
                    epochs= epochs_count, 
                    validation_data=(x_val, y_val), 
                    verbose=1, 
                    class_weight = class_weight,
                    callbacks=[cb])
# Out:
# Epoch 1/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.5580222277651872
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.5580222277651872
#
# 525/525 [==============================] - 6s 10ms/step - loss: 5.7008e-05 - accuracy: 0.6191 - val_loss: 0.7350 - val_accuracy: 0.4655
# Epoch 2/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.5952320082829147
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.5952320082829147
#
# 525/525 [==============================] - 4s 8ms/step - loss: 5.0142e-05 - accuracy: 0.6067 - val_loss: 0.6543 - val_accuracy: 0.5259
# Epoch 3/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.5608440754221767
#
# 525/525 [==============================] - 4s 8ms/step - loss: 4.7498e-05 - accuracy: 0.6298 - val_loss: 0.6957 - val_accuracy: 0.4504
# Epoch 4/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.5761945241638375
#
# 525/525 [==============================] - 4s 8ms/step - loss: 4.6312e-05 - accuracy: 0.6254 - val_loss: 0.6777 - val_accuracy: 0.4744
# Epoch 5/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.603017926231173
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.603017926231173
#
# 525/525 [==============================] - 5s 9ms/step - loss: 4.4094e-05 - accuracy: 0.6464 - val_loss: 0.6468 - val_accuracy: 0.5287
# Epoch 6/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.6105747252455039
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.6105747252455039
#
# 525/525 [==============================] - 4s 8ms/step - loss: 4.2703e-05 - accuracy: 0.6657 - val_loss: 0.6315 - val_accuracy: 0.5462
# Epoch 7/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.6589510223642638
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.6589510223642638
#
# 525/525 [==============================] - 4s 8ms/step - loss: 4.0711e-05 - accuracy: 0.6681 - val_loss: 0.5725 - val_accuracy: 0.6138
# Epoch 8/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0