# %%
# библиотеки....
import numpy as np 
import pandas as pd 
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Reshape, concatenate,  Flatten
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, SpatialDropout1D, MaxPooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import Callback
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, accuracy_score
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ЧТЕНИЕ И НОРМИРОВАНИЕ ДАННЫХ ИСХОДНОЙ ТАБЛИЦЫ

# %%
df = pd.read_csv('/content/drive/My Drive/Bases/makhachkala_weather_2011_2020_2.csv')

# %%
# нормируем столбцы (6 столбцов), которые по условию задачи
# участвуют в формировании вектора X
x_cols = ['t_air', 'rel_hum', 'P_atm', 'precip', 'wind_dir', 'wind_speed']

# нормировка данных по каждому столбцу к интервалу [0..1]
for col in x_cols:
  m = max(df[col])
  df[col] = df[col] / m

df
# Out:
#                   datetime     t_air  t_soil  t_dew  P_part_water  rel_hum  \
# 0      2011-01-01 00:00:00  0.170984     7.0    5.5          9.01     0.93
# 1      2011-01-01 03:00:00  0.160622     6.0    5.1          8.75     0.92
# 2      2011-01-01 06:00:00  0.150259     6.0    4.9          8.64     0.94
# 3      2011-01-01 09:00:00  0.152850     7.0    3.8          8.00     0.86
# 4      2011-01-01 12:00:00  0.134715     6.0    3.0          7.58     0.86
# ...                    ...       ...     ...    ...           ...      ...
# 29219  2020-12-31 09:00:00  0.111399     6.0    1.8          7.01     0.84
# 29220  2020-12-31 12:00:00  0.121762     6.0    2.4          7.29     0.85
# 29221  2020-12-31 15:00:00  0.113990     5.0    2.0          7.09     0.85
# 29222  2020-12-31 18:00:00  0.119171     2.0    2.0          7.07     0.83
# 29223  2020-12-31 21:00:00  0.098446     4.0    1.7          6.93     0.86
#
#        satur_def     P_atm  precip  wind_dir  wind_speed  shower  snow  fog  \
# 0           0.73  0.970389     0.0  0.833333      0.1875       0     0    0
# 1           0.73  0.969437     0.0  0.861111      0.2500       0     0    0
# 2           0.58  0.969723     0.0  0.916667      0.1875       0     0    0
# 3           1.28  0.969628     0.0  0.861111      0.3750       0     0    0
# 4           1.26  0.970199     0.0  0.888889      0.3750       0     0    0
# ...          ...       ...     ...       ...         ...     ...   ...  ...
# 29219       1.33  0.977625     0.0  0.886111      0.1875       0     0    0
# 29220       1.29  0.976959     0.0  0.802778      0.1250       0     0    0
# 29221       1.25  0.976673     0.0  0.905556      0.0625       0     0    1
# 29222       1.45  0.980577     0.0  0.433333      0.1875       0     0    0
# 29223       1.13  0.979625     0.0  0.363889      0.1875       0     0    0
#
#        strong_wind
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 29219            0
# 29220            0
# 29221            0
# 29222            0
# 29223            0
#
# [29224 rows x 15 columns]

# %% [markdown]
# ФУНКЦИЯ ГЕНЕРАЦИИ ВЫБОРКИ

# %%
# data - исходный датафрейм
# days_count - размер блока данных для X примера (по умолчанию 1 день)
# x_col_names - список колонок c которых генерируются векторы X
# y_col_name - колонка для генерации значений Y

def CreateSamples(data, x_col_names, y_col_name, days_count=1):
  
  block_size = days_count * 8 # размер блока данных

  pos = 0 # начальная позиция текущего смещения в датасете

  # обнуляем списки...
  samples_x = []
  samples_y = []
  
  Ex = False

  while not Ex: # цикл остановится, когда переменная Ex станет истиной 

    if pos + block_size < data.shape[0]: # если не дошли до конца....

      x_vec = []
      for x_col_name in x_col_names:
        x_vec.extend(data[x_col_name][pos:pos+block_size].to_list())
      
      y_vec = data[y_col_name][pos+block_size:pos+block_size+1].to_list()   

      samples_x.append(x_vec)
      samples_y.append(y_vec)

    else:

      Ex = True
    
    pos += 1 # сдвигаем позицию на 1

  # перевод данных в numpy массивы
  samples_x = np.array(samples_x)
  samples_y = np.array(samples_y).astype('float')

  return samples_x, samples_y

# %% [markdown]
# ГЕНЕРАЦИЯ ВЫБОРКИ

# %%
# размер блока данных
days_count = 7

# генерация выборки 
samples_x, samples_y = CreateSamples(df, x_cols, 'strong_wind', days_count)

# рамерность массивов
print(samples_x.shape)
print(samples_y.shape)
# Out:
# (29168, 336)
# (29168, 1)

# %% [markdown]
# МОДЕЛЬ НЕЙРОННОЙ СЕТИ
#
# Данные по 6 парамертам разделяются на 6 паралелльных веток для обработки одномерной сверткой, далее они объединяются и проходят через каскад полносвязных слоев.

# %%
# days_count - размер блока данных в днях

def CreateModel(days_count, activation='linear', dropout=0.1):

  input = Input((days_count*8*6,))
  
  x = Reshape((days_count*8*6, 1))(input)

  # свертка 1-го параметра
  x1 = SpatialDropout1D(dropout)(x[:, days_count*8*0:days_count*8*1, :])
  x1 = Conv1D(20, 7, activation=activation)(x1)
  x1 = MaxPooling1D(2)(x1)
  x1 = Flatten()(x1)

  # свертка 2-го параметра
  x2 = SpatialDropout1D(dropout)(x[:, days_count*8*1:days_count*8*2, :])
  x2 = Conv1D(20, 7, activation=activation)(x2)
  x2 = MaxPooling1D(2)(x2)
  x2 = Flatten()(x2)

  # свертка 3-го параметра
  x3 = SpatialDropout1D(dropout)(x[:, days_count*8*2:days_count*8*3, :])
  x3 = Conv1D(20, 7, activation=activation)(x3)
  x3 = MaxPooling1D(2)(x3)
  x3 = Flatten()(x3)
  
  # свертка 4-го параметра
  x4 = SpatialDropout1D(dropout)(x[:, days_count*8*3:days_count*8*4, :])
  x4 = Conv1D(20, 7, activation=activation)(x4)
  x4 = MaxPooling1D(2)(x4)
  x4 = Flatten()(x4)

  # свертка 5-го параметра
  x5 = SpatialDropout1D(dropout)(x[:, days_count*8*4:days_count*8*5, :])
  x5 = Conv1D(20, 7, activation=activation)(x5)
  x5 = MaxPooling1D(2)(x5)
  x5 = Flatten()(x5)

  # свертка 6-го параметра
  x6 = SpatialDropout1D(dropout)(x[:, days_count*8*5:days_count*8*6, :])
  x6 = Conv1D(20, 7, activation=activation)(x6)
  x6 = MaxPooling1D(2)(x6)
  x6 = Flatten()(x6)

  # оббъединяем результаты свертки в 1 слой
  x = concatenate([x1, x2, x3, x4, x5, x6])

  x = BatchNormalization()(x)
  x = Dense(500, activation=activation)(x)
  x = Dropout(dropout)(x)
  
  x = BatchNormalization()(x)
  x = Dense(200, activation=activation)(x)
  x = Dropout(dropout)(x)

  output = Dense(1, activation='sigmoid')(x) 

  return Model(input, output)

# %% [markdown]
# CALLBACK для фиксации лучшего обучения по метрике RECALL

# %%
# файл для сохранения лучших весов модели
model_save_file = '/content/drive/My Drive/Bases/model_best_w.h5'

# собственный коллбэк
class MyCallback(Callback):
  
  # инициализация
  def __init__(self, model, x_val, y_val):
    # модель
    self.model = model 
    # проверочная выборка
    self.x_val = x_val 
    self.y_val = y_val
    # начальный счет по средней метрике
    self.score = 0
    # список значений по метрике Recall
    self.recall_list = []
    # список значений по средней метрике
    self.general_list = []
       
  # подсчет метрики Recall для val  
  def calc_metric(self):
    y_pred = self.model.predict(self.x_val)
    y_p = np.around(y_pred).astype(int)
    y_t = np.around(self.y_val).astype(int)
    rec = recall_score(y_t, y_p, average='macro')
    acc = accuracy_score(y_t, y_p)
    return rec, acc
  
  # окончение каждой эпохи....
  def on_epoch_end(self, epoch, logs=None):
    rec, acc = self.calc_metric()
    self.recall_list.append(rec)
    score_0 = (rec + acc)/2
    self.general_list.append(score_0)
    print('\n\nТекущая точность (Recall+Accuracy)/2 =', score_0, '\n')
    if score_0 > self.score:
      self.score = score_0
      print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 =', score_0, '\n')
      self.model.save_weights(model_save_file)   

  # в конце обучения
  def on_train_end(self, logs=None):
    print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ =', self.score, '\n')
  
  # получение списка recall_list
  def get_recall_list(self):
    return self.recall_list

  # получение списка general_list
  def get_general_list(self):
    return self.general_list

# %% [markdown]
# ПАРАМЕТРЫ ОБУЧЕНИЯ

# %%
# параметры обучения

batch_size = 50

dropout = 0.25

activate_function = 'relu'

epochs_count = 50

learning_rate = 1e-4

# %% [markdown]
# ОБУЧЕНИЕ НЕЙРОННОЙ СЕТИ

# %%
# деление выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(samples_x, samples_y, 
                                                  test_size=0.1, random_state=1)

# %%
# настройка весов для классов модели (учет разбаллансировки)
weight_for_0 = 1.0 / (y_train == 0.0).sum()
weight_for_1 = 1.0 / (y_train == 1.0).sum()

class_weight = {0: weight_for_0, 1: weight_for_1}

print(class_weight)
# Out:
# {0: 3.982318505834097e-05, 1: 0.0008771929824561404}

# %%
# создание модели
model = CreateModel(days_count=days_count, 
                    activation=activate_function, dropout=dropout)  
cb = MyCallback(model, x_val, y_val)

# %%
# компиляция
model.compile(optimizer=Adam(learning_rate=learning_rate), 
              loss=['binary_crossentropy'], 
              metrics=['accuracy'])

# обучение
history = model.fit(x_train, y_train, 
                    batch_size = batch_size,
                    epochs= epochs_count, 
                    validation_data=(x_val, y_val), 
                    verbose=1, 
                    class_weight = class_weight,
                    callbacks=[cb])
# Out:
# Epoch 1/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.6531412823610696
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.6531412823610696
#
# 526/526 [==============================] - 7s 10ms/step - loss: 4.6291e-05 - accuracy: 0.6701 - val_loss: 0.6923 - val_accuracy: 0.5797
# Epoch 2/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.75451961023835
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.75451961023835
#
# 526/526 [==============================] - 4s 8ms/step - loss: 4.3611e-05 - accuracy: 0.6944 - val_loss: 0.5283 - val_accuracy: 0.7357
# Epoch 3/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7476751920635631
#
# 526/526 [==============================] - 4s 8ms/step - loss: 4.0806e-05 - accuracy: 0.7244 - val_loss: 0.5369 - val_accuracy: 0.7216
# Epoch 4/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7914301904033609
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.7914301904033609
#
# 526/526 [==============================] - 5s 10ms/step - loss: 3.8978e-05 - accuracy: 0.7381 - val_loss: 0.4423 - val_accuracy: 0.7943
# Epoch 5/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.834241705119211
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.834241705119211
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.8814e-05 - accuracy: 0.7334 - val_loss: 0.3566 - val_accuracy: 0.8632
# Epoch 6/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8371911128801246
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8371911128801246
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.7342e-05 - accuracy: 0.7529 - val_loss: 0.3645 - val_accuracy: 0.8519
# Epoch 7/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8275392485251905
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.4450e-05 - accuracy: 0.7640 - val_loss: 0.3278 - val_accuracy: 0.8721
# Epoch 8/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8588285792428714
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8588285792428714
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.3053e-05 - accuracy: 0.7813 - val_loss: 0.2815 - val_accuracy: 0.9006
# Epoch 9/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8509008348923823
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.2492e-05 - accuracy: 0.7830 - val_loss: 0.2767 - val_accuracy: 0.8927
# Epoch 10/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8393411176268684
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.1747e-05 - accuracy: 0.7909 - val_loss: 0.2743 - val_accuracy: 0.8927
# Epoch 11/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8371932319091364
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.0269e-05 - accuracy: 0.7995 - val_loss: 0.2841 - val_accuracy: 0.8848
# Epoch 12/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.85290887805836
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.8567e-05 - accuracy: 0.8063 - val_loss: 0.2450 - val_accuracy: 0.9105
# Epoch 13/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8492560194806507
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.7454e-05 - accuracy: 0.8181 - val_loss: 0.2385 - val_accuracy: 0.9057
# Epoch 14/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8495169379504871
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.7732e-05 - accuracy: 0.8101 - val_loss: 0.2285 - val_accuracy: 0.9061
# Epoch 15/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8568226551059055
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.5644e-05 - accuracy: 0.8242 - val_loss: 0.2167 - val_accuracy: 0.9157
# Epoch 16/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8552383776532149
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.5156e-05 - accuracy: 0.8247 - val_loss: 0.1896 - val_accuracy: 0.9338
# Epoch 17/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.853269986783594
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.4890e-05 - accuracy: 0.8312 - val_loss: 0.2273 - val_accuracy: 0.9085
# Epoch 18/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8436181224286599
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.3515e-05 - accuracy: 0.8370 - val_loss: 0.1918 - val_accuracy: 0.9287
# Epoch 19/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8627632419531013
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8627632419531013
#
# 526/526 [==============================] - 5s 10ms/step - loss: 2.3716e-05 - accuracy: 0.8362 - val_loss: 0.2090 - val_accuracy: 0.9184
# Epoch 20/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8529903016800852
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.2671e-05 - accuracy: 0.8450 - val_loss: 0.1874 - val_accuracy: 0.9284
# Epoch 21/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8518464375453421
#
# 526/526 [==============================] - 5s 10ms/step - loss: 2.1993e-05 - accuracy: 0.8457 - val_loss: 0.1872 - val_accuracy: 0.9294
# Epoch 22/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8458056604427486
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.1179e-05 - accuracy: 0.8545 - val_loss: 0.1840 - val_accuracy: 0.9290
# Epoch 23/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8477113943243166
#
# 526/526 [==============================] - 5s 9ms/step - loss: 2.0817e-05 - accuracy: 0.8621 - val_loss: 0.2160 - val_accuracy: 0.9164
# Epoch 24/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8525686549958101
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.9798e-05 - accuracy: 0.8579 - val_loss: 0.1914 - val_accuracy: 0.9253
# Epoch 25/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8496192472348966
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.9045e-05 - accuracy: 0.8709 - val_loss: 0.1716 - val_accuracy: 0.9366
# Epoch 26/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8508236493286807
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.8421e-05 - accuracy: 0.8727 - val_loss: 0.1694 - val_accuracy: 0.9407
# Epoch 27/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.824673383415014
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.7980e-05 - accuracy: 0.8741 - val_loss: 0.1787 - val_accuracy: 0.9342
# Epoch 28/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8499803559601307
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.6539e-05 - accuracy: 0.8877 - val_loss: 0.1752 - val_accuracy: 0.9345
# Epoch 29/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.836293638639569
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.7437e-05 - accuracy: 0.8838 - val_loss: 0.1648 - val_accuracy: 0.9393
# Epoch 30/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8232080628513934
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.7803e-05 - accuracy: 0.8852 - val_loss: 0.1737 - val_accuracy: 0.9297
# Epoch 31/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8178707365655956
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.5661e-05 - accuracy: 0.8928 - val_loss: 0.1577 - val_accuracy: 0.9455
# Epoch 32/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8487759538663464
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.6464e-05 - accuracy: 0.8913 - val_loss: 0.1787 - val_accuracy: 0.9304
# Epoch 33/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8273431060724186
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.5924e-05 - accuracy: 0.8892 - val_loss: 0.1621 - val_accuracy: 0.9427
# Epoch 34/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8294304538311097
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.5427e-05 - accuracy: 0.8982 - val_loss: 0.1626 - val_accuracy: 0.9455
# Epoch 35/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8304135897514142
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.3966e-05 - accuracy: 0.9064 - val_loss: 0.1645 - val_accuracy: 0.9417
# Epoch 36/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.800852617096202
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3911e-05 - accuracy: 0.9074 - val_loss: 0.1530 - val_accuracy: 0.9510
# Epoch 37/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8194153617219296
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.4078e-05 - accuracy: 0.9043 - val_loss: 0.1797 - val_accuracy: 0.9349
# Epoch 38/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8155830082961092
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.4072e-05 - accuracy: 0.9032 - val_loss: 0.1606 - val_accuracy: 0.9475
# Epoch 39/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8152218995708751
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3392e-05 - accuracy: 0.9059 - val_loss: 0.1622 - val_accuracy: 0.9496
# Epoch 40/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8058497203194498
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3429e-05 - accuracy: 0.9121 - val_loss: 0.1569 - val_accuracy: 0.9499
# Epoch 41/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8131345518121841
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2756e-05 - accuracy: 0.9130 - val_loss: 0.1618 - val_accuracy: 0.9469
# Epoch 42/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8236505951983526
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2644e-05 - accuracy: 0.9150 - val_loss: 0.1684 - val_accuracy: 0.9455
# Epoch 43/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8160443072767409
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2564e-05 - accuracy: 0.9130 - val_loss: 0.1728 - val_accuracy: 0.9431
# Epoch 44/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8130343615567863
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2889e-05 - accuracy: 0.9146 - val_loss: 0.1704 - val_accuracy: 0.9493
# Epoch 45/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8135958507928158
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2452e-05 - accuracy: 0.9144 - val_loss: 0.1744 - val_accuracy: 0.9424
# Epoch 46/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8139173072216932
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2073e-05 - accuracy: 0.9195 - val_loss: 0.1751 - val_accuracy: 0.9479
# Epoch 47/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8129341713013887
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.0942e-05 - accuracy: 0.9253 - val_loss: 0.1686 - val_accuracy: 0.9517
# Epoch 48/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7990261878073472
#
# 526/526 [==============================] - 5s 10ms/step - loss: 1.2478e-05 - accuracy: 0.9202 - val_loss: 0.1703 - val_accuracy: 0.9486
# Epoch 49/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8050064269508996
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.1529e-05 - accuracy: 0.9209 - val_loss: 0.1758 - val_accuracy: 0.9438
# Epoch 50/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.823550404942955
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.0673e-05 - accuracy: 0.9266 - val_loss: 0.1780 - val_accuracy: 0.9479
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ = 0.8627632419531013

# %% [markdown]
# АРХИТЕКТУРА МОДЕЛИ

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ГРАФИКИ ОБУЧЕНИЯ

# %%
# графики обучения
def cm_to_inch(value):
    return value/2.54

plt.figure(figsize=(cm_to_inch(30),cm_to_inch(15)))

plt.title('Графики обучения прогнозирования параметра "Сильный ветер"', 
          pad=30, fontsize=16)

plt.plot(history.history['accuracy'], 
         label='Точность Accuracy на обучающем наборе', linewidth=3)
plt.plot(history.history['val_accuracy'], 
         label='Точность Accuracy на проверочном наборе', linewidth=3)
plt.plot(cb.get_recall_list(), 
         label='Точность Recall на проверочном наборе', linewidth=3)
plt.plot(cb.get_general_list(), 
         label='Точность (Recall+Accuracy)/2 на проверочном наборе', linewidth=3)

plt.xlabel('Эпоха обучения', fontsize=14)
plt.ylabel('Точность', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)
plt.grid(True)
plt.show()
