# %%
# библиотеки....
import numpy as np 
import pandas as pd 
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import Callback
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, accuracy_score
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ЧТЕНИЕ И НОРМИРОВАНИЕ ДАННЫХ ИСХОДНОЙ ТАБЛИЦЫ

# %%
df = pd.read_csv('/content/drive/My Drive/Bases/makhachkala_weather_2011_2020_2.csv')

# %%
# нормируем столбцы (6 столбцов), которые по условию задачи
# участвуют в формировании вектора X
x_cols = ['t_air', 'rel_hum', 'P_atm', 'precip', 'wind_dir', 'wind_speed']

# нормировка данных по каждому столбцу к интервалу [0..1]
for col in x_cols:
  m = max(df[col])
  df[col] = df[col] / m

df
# Out:
#                   datetime     t_air  t_soil  t_dew  P_part_water  rel_hum  \
# 0      2011-01-01 00:00:00  0.170984     7.0    5.5          9.01     0.93
# 1      2011-01-01 03:00:00  0.160622     6.0    5.1          8.75     0.92
# 2      2011-01-01 06:00:00  0.150259     6.0    4.9          8.64     0.94
# 3      2011-01-01 09:00:00  0.152850     7.0    3.8          8.00     0.86
# 4      2011-01-01 12:00:00  0.134715     6.0    3.0          7.58     0.86
# ...                    ...       ...     ...    ...           ...      ...
# 29219  2020-12-31 09:00:00  0.111399     6.0    1.8          7.01     0.84
# 29220  2020-12-31 12:00:00  0.121762     6.0    2.4          7.29     0.85
# 29221  2020-12-31 15:00:00  0.113990     5.0    2.0          7.09     0.85
# 29222  2020-12-31 18:00:00  0.119171     2.0    2.0          7.07     0.83
# 29223  2020-12-31 21:00:00  0.098446     4.0    1.7          6.93     0.86
#
#        satur_def     P_atm  precip  wind_dir  wind_speed  shower  snow  fog  \
# 0           0.73  0.970389     0.0  0.833333      0.1875       0     0    0
# 1           0.73  0.969437     0.0  0.861111      0.2500       0     0    0
# 2           0.58  0.969723     0.0  0.916667      0.1875       0     0    0
# 3           1.28  0.969628     0.0  0.861111      0.3750       0     0    0
# 4           1.26  0.970199     0.0  0.888889      0.3750       0     0    0
# ...          ...       ...     ...       ...         ...     ...   ...  ...
# 29219       1.33  0.977625     0.0  0.886111      0.1875       0     0    0
# 29220       1.29  0.976959     0.0  0.802778      0.1250       0     0    0
# 29221       1.25  0.976673     0.0  0.905556      0.0625       0     0    1
# 29222       1.45  0.980577     0.0  0.433333      0.1875       0     0    0
# 29223       1.13  0.979625     0.0  0.363889      0.1875       0     0    0
#
#        strong_wind
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 29219            0
# 29220            0
# 29221            0
# 29222            0
# 29223            0
#
# [29224 rows x 15 columns]

# %% [markdown]
# ФУНКЦИЯ ГЕНЕРАЦИИ ВЫБОРКИ

# %%
# data - исходный датафрейм
# days_count - размер блока данных для X примера (по умолчанию 1 день)
# x_col_names - список колонок c которых генерируются векторы X
# y_col_name - колонка для генерации значений Y

def CreateSamples(data, x_col_names, y_col_name, days_count=1):
  
  block_size = days_count * 8 # размер блока данных

  pos = 0 # начальная позиция текущего смещения в датасете

  # обнуляем списки...
  samples_x = []
  samples_y = []
  
  Ex = False

  while not Ex: # цикл остановится, когда переменная Ex станет истиной 

    if pos + block_size < data.shape[0]: # если не дошли до конца....

      x_vec = []
      for x_col_name in x_col_names:
        x_vec.extend(data[x_col_name][pos:pos+block_size].to_list())
      
      y_vec = data[y_col_name][pos+block_size:pos+block_size+1].to_list()   

      samples_x.append(x_vec)
      samples_y.append(y_vec)

    else:

      Ex = True
    
    pos += 1 # сдвигаем позицию на 1

  # перевод данных в numpy массивы
  samples_x = np.array(samples_x)
  samples_y = np.array(samples_y).astype('float')

  return samples_x, samples_y

# %% [markdown]
# ГЕНЕРАЦИЯ ВЫБОРКИ

# %%
# размер блока данных
days_count = 7

# генерация выборки 
samples_x, samples_y = CreateSamples(df, x_cols, 'strong_wind', days_count)

# рамерность массивов
print(samples_x.shape)
print(samples_y.shape)
# Out:
# (29168, 336)
# (29168, 1)

# %% [markdown]
# МОДЕЛЬ НЕЙРОННОЙ СЕТИ (только полносвязные слои)

# %%
# days_count - размер блока данных в днях

def CreateModel(days_count, activation='linear', dropout=0.1):

  input = Input((days_count*8*6,))
  
  x = BatchNormalization()(input)
  x = Dense(1000, activation=activation)(x)
  x = Dropout(dropout)(x)

  x = BatchNormalization()(x)
  x = Dense(500, activation=activation)(x)
  x = Dropout(dropout)(x)
  
  x = BatchNormalization()(x)
  x = Dense(200, activation=activation)(x)
  x = Dropout(dropout)(x)

  x = BatchNormalization()(x)
  x = Dense(100, activation=activation)(x)
  x = Dropout(dropout)(x)

  output = Dense(1, activation='sigmoid')(x) 

  return Model(input, output)

# %% [markdown]
# CALLBACK для фиксации лучшего обучения по метрике RECALL

# %%
# файл для сохранения лучших весов модели
model_save_file = '/content/drive/My Drive/Bases/model_best_w_d.h5'

# собственный коллбэк
class MyCallback(Callback):
  
  # инициализация
  def __init__(self, model, x_val, y_val):
    # модель
    self.model = model 
    # проверочная выборка
    self.x_val = x_val 
    self.y_val = y_val
    # начальный счет по средней метрике
    self.score = 0
    # список значений по метрике Recall
    self.recall_list = []
    # список значений по средней метрике
    self.general_list = []
       
  # подсчет метрики Recall для val  
  def calc_metric(self):
    y_pred = self.model.predict(self.x_val)
    y_p = np.around(y_pred).astype(int)
    y_t = np.around(self.y_val).astype(int)
    rec = recall_score(y_t, y_p, average='macro')
    acc = accuracy_score(y_t, y_p)
    return rec, acc
  
  # окончение каждой эпохи....
  def on_epoch_end(self, epoch, logs=None):
    rec, acc = self.calc_metric()
    self.recall_list.append(rec)
    score_0 = (rec + acc)/2
    self.general_list.append(score_0)
    print('\n\nТекущая точность (Recall+Accuracy)/2 =', score_0, '\n')
    if score_0 > self.score:
      self.score = score_0
      print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 =', score_0, '\n')
      self.model.save_weights(model_save_file)   

  # в конце обучения
  def on_train_end(self, logs=None):
    print('\n\n!!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ =', self.score, '\n')
  
  # получение списка recall_list
  def get_recall_list(self):
    return self.recall_list

  # получение списка general_list
  def get_general_list(self):
    return self.general_list

# %% [markdown]
# ПАРАМЕТРЫ ОБУЧЕНИЯ

# %%
# параметры обучения

batch_size = 50

dropout = 0.25

activate_function = 'relu'

epochs_count = 50

learning_rate = 1e-4

# %% [markdown]
# ОБУЧЕНИЕ НЕЙРОННОЙ СЕТИ

# %%
# деление выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(samples_x, samples_y, 
                                                  test_size=0.1, random_state=1)

# %%
# настройка весов для классов модели (учет разбаллансировки)
weight_for_0 = 1.0 / (y_train == 0.0).sum()
weight_for_1 = 1.0 / (y_train == 1.0).sum()

class_weight = {0: weight_for_0, 1: weight_for_1}

print(class_weight)
# Out:
# {0: 3.982318505834097e-05, 1: 0.0008771929824561404}

# %%
# создание модели
model = CreateModel(days_count=days_count, 
                    activation=activate_function, dropout=dropout)  
cb = MyCallback(model, x_val, y_val)

# %%
# компиляция
model.compile(optimizer=Adam(learning_rate=learning_rate), 
              loss=['binary_crossentropy'], 
              metrics=['accuracy'])

# обучение
history = model.fit(x_train, y_train, 
                    batch_size = batch_size,
                    epochs= epochs_count, 
                    validation_data=(x_val, y_val), 
                    verbose=1, 
                    class_weight = class_weight,
                    callbacks=[cb])
# Out:
# Epoch 1/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.7692708871009415
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.7692708871009415
#
# 526/526 [==============================] - 7s 8ms/step - loss: 4.9018e-05 - accuracy: 0.5826 - val_loss: 0.5312 - val_accuracy: 0.7449
# Epoch 2/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8080475488511638
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8080475488511638
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.8426e-05 - accuracy: 0.7320 - val_loss: 0.4578 - val_accuracy: 0.7984
# Epoch 3/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8057598205816775
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.4098e-05 - accuracy: 0.7767 - val_loss: 0.4467 - val_accuracy: 0.8005
# Epoch 4/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8244854124508556
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8244854124508556
#
# 526/526 [==============================] - 4s 8ms/step - loss: 3.1390e-05 - accuracy: 0.8070 - val_loss: 0.4184 - val_accuracy: 0.8200
# Epoch 5/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8264120319951079
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8264120319951079
#
# 526/526 [==============================] - 4s 7ms/step - loss: 3.0363e-05 - accuracy: 0.8186 - val_loss: 0.4033 - val_accuracy: 0.8200
# Epoch 6/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8222978744367669
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.8476e-05 - accuracy: 0.8208 - val_loss: 0.4026 - val_accuracy: 0.8197
# Epoch 7/50
# 92/92 [==============================] - 0s 3ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8412447324794248
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8412447324794248
#
# 526/526 [==============================] - 6s 10ms/step - loss: 2.6439e-05 - accuracy: 0.8346 - val_loss: 0.3464 - val_accuracy: 0.8471
# Epoch 8/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8443757541174612
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8443757541174612
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.5454e-05 - accuracy: 0.8397 - val_loss: 0.3369 - val_accuracy: 0.8512
# Epoch 9/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.840662357580711
#
# 526/526 [==============================] - 5s 9ms/step - loss: 2.3534e-05 - accuracy: 0.8492 - val_loss: 0.3476 - val_accuracy: 0.8413
# Epoch 10/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.846924400856784
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.846924400856784
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.2729e-05 - accuracy: 0.8534 - val_loss: 0.3337 - val_accuracy: 0.8495
# Epoch 11/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8475067757554977
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8475067757554977
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.1498e-05 - accuracy: 0.8607 - val_loss: 0.3259 - val_accuracy: 0.8553
# Epoch 12/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8475067757554977
#
# 526/526 [==============================] - 4s 7ms/step - loss: 2.0639e-05 - accuracy: 0.8635 - val_loss: 0.3215 - val_accuracy: 0.8553
# Epoch 13/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8525644169377866
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8525644169377866
#
# 526/526 [==============================] - 4s 8ms/step - loss: 2.0479e-05 - accuracy: 0.8670 - val_loss: 0.3014 - val_accuracy: 0.8594
# Epoch 14/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8624187808325279
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8624187808325279
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.8746e-05 - accuracy: 0.8730 - val_loss: 0.3041 - val_accuracy: 0.8673
# Epoch 15/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8544117318893254
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.8023e-05 - accuracy: 0.8780 - val_loss: 0.2892 - val_accuracy: 0.8745
# Epoch 16/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8409441617132316
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.8216e-05 - accuracy: 0.8799 - val_loss: 0.3350 - val_accuracy: 0.8543
# Epoch 17/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8481893409096091
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.7823e-05 - accuracy: 0.8826 - val_loss: 0.3152 - val_accuracy: 0.8588
# Epoch 18/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8609346936352349
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.5559e-05 - accuracy: 0.8904 - val_loss: 0.2710 - val_accuracy: 0.8831
# Epoch 19/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8557977478602325
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.4905e-05 - accuracy: 0.8988 - val_loss: 0.2504 - val_accuracy: 0.8941
# Epoch 20/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8621787480253758
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.5359e-05 - accuracy: 0.9015 - val_loss: 0.2875 - val_accuracy: 0.8797
# Epoch 21/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8614565305749076
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.4831e-05 - accuracy: 0.8988 - val_loss: 0.2673 - val_accuracy: 0.8838
# Epoch 22/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8634436880782009
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8634436880782009
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.4631e-05 - accuracy: 0.9035 - val_loss: 0.2670 - val_accuracy: 0.8889
# Epoch 23/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8639258727215169
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8639258727215169
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3683e-05 - accuracy: 0.9092 - val_loss: 0.2514 - val_accuracy: 0.8972
# Epoch 24/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8592293402644622
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.3402e-05 - accuracy: 0.9099 - val_loss: 0.2707 - val_accuracy: 0.8910
# Epoch 25/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8575636391900462
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.2402e-05 - accuracy: 0.9154 - val_loss: 0.2767 - val_accuracy: 0.8913
# Epoch 26/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8656521117549738
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8656521117549738
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.2687e-05 - accuracy: 0.9188 - val_loss: 0.2495 - val_accuracy: 0.9020
# Epoch 27/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8641867911913533
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.1685e-05 - accuracy: 0.9224 - val_loss: 0.2609 - val_accuracy: 0.8975
# Epoch 28/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8724965299297607
#
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 = 0.8724965299297607
#
# 526/526 [==============================] - 5s 9ms/step - loss: 1.1363e-05 - accuracy: 0.9241 - val_loss: 0.2195 - val_accuracy: 0.9160
# Epoch 29/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8590289597536668
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.1163e-05 - accuracy: 0.9278 - val_loss: 0.2727 - val_accuracy: 0.8958
# Epoch 30/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8659130302248103
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.1807e-05 - accuracy: 0.9248 - val_loss: 0.2534 - val_accuracy: 0.9023
# Epoch 31/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8588494649055556
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.0022e-05 - accuracy: 0.9317 - val_loss: 0.2382 - val_accuracy: 0.9133
# Epoch 32/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8671383179812787
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.0042e-05 - accuracy: 0.9336 - val_loss: 0.2304 - val_accuracy: 0.9191
# Epoch 33/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8664954051235241
#
# 526/526 [==============================] - 4s 7ms/step - loss: 1.0245e-05 - accuracy: 0.9349 - val_loss: 0.2483 - val_accuracy: 0.9081
# Epoch 34/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8674388887474718
#
# 526/526 [==============================] - 4s 8ms/step - loss: 9.2400e-06 - accuracy: 0.9400 - val_loss: 0.2445 - val_accuracy: 0.9119
# Epoch 35/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8692653180363265
#
# 526/526 [==============================] - 4s 8ms/step - loss: 1.0116e-05 - accuracy: 0.9365 - val_loss: 0.2505 - val_accuracy: 0.9143
# Epoch 36/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8610975408786853
#
# 526/526 [==============================] - 4s 7ms/step - loss: 9.5354e-06 - accuracy: 0.9409 - val_loss: 0.2405 - val_accuracy: 0.9188
# Epoch 37/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8617801060327968
#
# 526/526 [==============================] - 4s 7ms/step - loss: 9.1044e-06 - accuracy: 0.9408 - val_loss: 0.2377 - val_accuracy: 0.9222
# Epoch 38/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8560002474000397
#
# 526/526 [==============================] - 4s 8ms/step - loss: 8.2279e-06 - accuracy: 0.9481 - val_loss: 0.2379 - val_accuracy: 0.9222
# Epoch 39/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8614586496039194
#
# 526/526 [==============================] - 4s 7ms/step - loss: 9.2826e-06 - accuracy: 0.9430 - val_loss: 0.2523 - val_accuracy: 0.9167
# Epoch 40/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8577056007708124
#
# 526/526 [==============================] - 4s 8ms/step - loss: 8.2384e-06 - accuracy: 0.9477 - val_loss: 0.2573 - val_accuracy: 0.9143
# Epoch 41/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8574050300046194
#
# 526/526 [==============================] - 4s 7ms/step - loss: 8.1066e-06 - accuracy: 0.9480 - val_loss: 0.2452 - val_accuracy: 0.9215
# Epoch 42/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8698873452313969
#
# 526/526 [==============================] - 4s 7ms/step - loss: 8.1197e-06 - accuracy: 0.9486 - val_loss: 0.2704 - val_accuracy: 0.9126
# Epoch 43/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8647503994563945
#
# 526/526 [==============================] - 4s 7ms/step - loss: 8.3798e-06 - accuracy: 0.9470 - val_loss: 0.2402 - val_accuracy: 0.9236
# Epoch 44/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8321982477149003
#
# 526/526 [==============================] - 4s 7ms/step - loss: 7.4206e-06 - accuracy: 0.9522 - val_loss: 0.2535 - val_accuracy: 0.9188
# Epoch 45/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8457660081463918
#
# 526/526 [==============================] - 4s 7ms/step - loss: 6.8167e-06 - accuracy: 0.9566 - val_loss: 0.2167 - val_accuracy: 0.9366
# Epoch 46/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8533514104053193
#
# 526/526 [==============================] - 4s 7ms/step - loss: 7.2359e-06 - accuracy: 0.9557 - val_loss: 0.2437 - val_accuracy: 0.9263
# Epoch 47/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8474713615171646
#
# 526/526 [==============================] - 4s 8ms/step - loss: 7.4601e-06 - accuracy: 0.9567 - val_loss: 0.2345 - val_accuracy: 0.9287
# Epoch 48/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8424137203348756
#
# 526/526 [==============================] - 4s 7ms/step - loss: 7.0185e-06 - accuracy: 0.9558 - val_loss: 0.2384 - val_accuracy: 0.9246
# Epoch 49/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8536728668341966
#
# 526/526 [==============================] - 4s 7ms/step - loss: 7.1452e-06 - accuracy: 0.9576 - val_loss: 0.2237 - val_accuracy: 0.9318
# Epoch 50/50
# 92/92 [==============================] - 0s 2ms/step
#
#
# Текущая точность (Recall+Accuracy)/2 = 0.8514853288201079
#
# 526/526 [==============================] - 4s 7ms/step - loss: 6.8237e-06 - accuracy: 0.9566 - val_loss: 0.2244 - val_accuracy: 0.9314
#
#
# !!!!!!!!ЛУЧШАЯ ТОЧНОСТЬ (RECALL+ACCURACY)/2 ОБУЧЕНИЯ = 0.8724965299297607

# %% [markdown]
# АРХИТЕКТУРА МОДЕЛИ

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ГРАФИКИ ОБУЧЕНИЯ

# %%
# графики обучения
def cm_to_inch(value):
    return value/2.54

plt.figure(figsize=(cm_to_inch(30),cm_to_inch(15)))

plt.title('Графики обучения прогнозирования параметра "Сильный ветер"', 
          pad=30, fontsize=16)

plt.plot(history.history['accuracy'], 
         label='Точность Accuracy на обучающем наборе', linewidth=3)
plt.plot(history.history['val_accuracy'], 
         label='Точность Accuracy на проверочном наборе', linewidth=3)
plt.plot(cb.get_recall_list(), 
         label='Точность Recall на проверочном наборе', linewidth=3)
plt.plot(cb.get_general_list(), 
         label='Точность (Recall+Accuracy)/2 на проверочном наборе', linewidth=3)

plt.xlabel('Эпоха обучения', fontsize=14)
plt.ylabel('Точность', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)
plt.grid(True)
plt.show()
